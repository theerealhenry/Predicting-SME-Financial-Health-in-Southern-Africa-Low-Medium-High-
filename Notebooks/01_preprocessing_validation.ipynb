# %%
import pandas as pd
from src.preprocessing import PreprocessConfig, preprocess_train_test

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_rows", 200)

train = pd.read_csv("D:\\dataorg-financial-health-prediction-challenge20251204-19827-m2tn1n\\Train.csv")
test  = pd.read_csv("D:\\dataorg-financial-health-prediction-challenge20251204-19827-m2tn1n\\Test.csv")

cfg = PreprocessConfig(id_col="ID", target_col="Target")

train_clean, test_clean = preprocess_train_test(train, test, cfg, for_model="catboost")

print(train_clean.shape, test_clean.shape)
# Out:
# (9618, 47) (2405, 46)

# %%
train_clean.sample(100)
# Out:
#              ID   country  owner_age attitude_stable_business_environment  \
# 6692  ID_W74YRT    malawi       26.0                           don't know
# 9108  ID_PL6UZA  eswatini       49.0                                  yes
# 2609  ID_KS9URX   lesotho       55.0                                  yes
# 7081  ID_VC1U5W    malawi       29.0                                   no
# 6031  ID_8RM9II   lesotho       39.0                                   no
# 6929  ID_UXHPUQ  zimbabwe       42.0                                  yes
# 3980  ID_0DM9IF  eswatini       30.0                                  yes
# 3387  ID_MZVCG8  zimbabwe       43.0                                  yes
# 5470  ID_4L2E4F  eswatini       31.0                                  yes
# 264   ID_IK209E   lesotho       54.0                                   no
# 1863  ID_7P2R5J   lesotho       32.0                                  yes
# 3473  ID_9NXMKT   lesotho       40.0                                  yes
# ...
